# %%
import pandas as pd

# %%
refined_timestamps = pd.read_csv('refined_exp_timestamps.csv')

# %%
refined_timestamps[100:150]
# Out:
#      Participant  Type  File     Start       End Remarks
# 100          9.0   2.0   1.0  11:38:18  11:42:49     NaN
# 101          9.0   2.0   2.0  11:42:49  11:45:07     NaN
# 102          9.0   2.0   3.0  11:45:07  11:49:22     NaN
# 103          9.0   2.0   4.0  11:49:22  11:53:42     NaN
# 104          9.0   3.0   1.0  11:54:21  11:58:44     NaN
# 105          9.0   3.0   2.0  11:58:44  12:01:11     NaN
# 106          9.0   3.0   3.0  12:01:11  12:04:38     NaN
# 107          9.0   3.0   4.0  12:04:38  12:07:30     NaN
# 108         10.0   1.0   1.0  13:16:11   5:43:26     NaN
# 109         10.0   1.0   2.0   5:43:26   5:47:57     NaN
# 110         10.0   1.0   3.0   5:47:57   5:50:24     NaN
# 111         10.0   1.0   4.0   5:50:24   5:52:11     NaN
# 112         10.0   2.0   1.0   5:55:11   5:59:03     NaN
# 113         10.0   2.0   2.0   5:59:03   6:03:15     NaN
# 114         10.0   2.0   3.0   6:03:15   6:06:23     NaN
# ...

# %%
refined_timestamps[refined_timestamps['File']==1]['Start'].isna().sum()
# Out:
# np.int64(0)

# %%
refined_timestamps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Participant  360 non-null    float64
#  1   Type         360 non-null    float64
#  2   File         360 non-null    float64
#  3   Start        196 non-null    object
#  4   End          355 non-null    object
#  5   Remarks      1 non-null      object
# dtypes: float64(3), object(3)
# memory usage: 17.0+ KB

# %%
refined_timestamps['Start'].fillna(refined_timestamps['End'].shift(1),inplace=True)
# Out:
# C:\Users\karti\AppData\Local\Temp\ipykernel_23120\3598051341.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   refined_timestamps['Start'].fillna(refined_timestamps['End'].shift(1),inplace=True)

# %%
refined_timestamps[100:150]
# Out:
#      Participant  Type  File     Start       End Remarks
# 100          9.0   2.0   1.0  11:38:18  11:42:49     NaN
# 101          9.0   2.0   2.0  11:42:49  11:45:07     NaN
# 102          9.0   2.0   3.0  11:45:07  11:49:22     NaN
# 103          9.0   2.0   4.0  11:49:22  11:53:42     NaN
# 104          9.0   3.0   1.0  11:54:21  11:58:44     NaN
# 105          9.0   3.0   2.0  11:58:44  12:01:11     NaN
# 106          9.0   3.0   3.0  12:01:11  12:04:38     NaN
# 107          9.0   3.0   4.0  12:04:38  12:07:30     NaN
# 108         10.0   1.0   1.0  13:16:11   5:43:26     NaN
# 109         10.0   1.0   2.0   5:43:26   5:47:57     NaN
# 110         10.0   1.0   3.0   5:47:57   5:50:24     NaN
# 111         10.0   1.0   4.0   5:50:24   5:52:11     NaN
# 112         10.0   2.0   1.0   5:55:11   5:59:03     NaN
# 113         10.0   2.0   2.0   5:59:03   6:03:15     NaN
# 114         10.0   2.0   3.0   6:03:15   6:06:23     NaN
# ...

# %%
refined_timestamps.to_csv('refined_exp_timestamps.csv',index=False)
